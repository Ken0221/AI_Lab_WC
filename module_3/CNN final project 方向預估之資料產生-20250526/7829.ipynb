# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, Input
from itertools import combinations
from tensorflow.keras.callbacks import Callback
import tensorflow_probability as tfp

# %%
config = {
    'epochs': 50,
    'batch_size': 128,
    'learning_rate': 0.001,
    'activation': 'gelu',
    'dropout_rate': 0.25,
    'val_size': 0.2,
}

# %% [markdown]
# # Data Loader

# %%
file_dir = './radar_data/special/'
# training data
# input
mat = sio.loadmat(file_dir + 'train_Covariance.mat')
train_input = mat['Covariance']
train_input = np.float32(train_input)
# print("train_input shape:", train_input.shape)

# output
mat = sio.loadmat(file_dir + 'train_Label.mat')
train_output_old = mat['Label']
train_output_old = np.float32(train_output_old)
train_output = train_output_old

dataset = tf.data.Dataset.from_tensor_slices((train_input, train_output))
# print orginal number of samples in train_dataset
num_samples_train_org = sum(1 for _ in dataset)
print("Original number of samples in train_dataset:", num_samples_train_org)


# 將 validation 資料從原始資料中移除
# train_dataset = combined_dataset.skip(int(num_samples_train_org * config['val_size']))

train_dataset = (
    dataset
    .shuffle(buffer_size=num_samples_train_org)
    .batch(config['batch_size'])
    .prefetch(tf.data.AUTOTUNE)
)
    
# print("train_dataset.shape:", train_dataset.element_spec)
# print number of samples in train_dataset
total_samples_train = sum(batch[0].shape[0] for batch in train_dataset)
print("Total number of training samples (after batching):", total_samples_train)


# testing data
# input
mat = sio.loadmat(file_dir + 'test_Covariance.mat')
test_input = mat['Covariance']
test_input = np.float32(test_input)
# print("test_input shape:", test_input.shape)

# output
mat = sio.loadmat(file_dir + 'test_Label.mat')
test_output_old = mat['Label']
test_output_old = np.float32(test_output_old)
test_output = test_output_old

dataset = tf.data.Dataset.from_tensor_slices((test_input, test_output))
test_dataset = dataset.batch(config['batch_size']).prefetch(tf.data.AUTOTUNE)

# print("test_output shape:", test_output.shape)
# print("test_dataset.shape:", test_dataset.element_spec)
# print number of samples in test_dataset
total_samples_test = sum(batch[0].shape[0] for batch in test_dataset)
print("Total number of testing samples (after batching):", total_samples_test)
# Out:
# Original number of samples in train_dataset: 57344
# Total number of training samples (after batching): 57344
# Total number of testing samples (after batching): 14336

# %% [markdown]
# # model

# %%
# model = keras.Sequential([
#     keras.layers.Conv2D(128, (3, 3), input_shape=(train_input.shape[1], train_input.shape[2], 2)),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.Conv2D(128, (3, 3), padding='same'),
#     keras.layers.MaxPooling2D((2, 2)),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
    
#     keras.layers.Conv2D(256, (3, 3), padding='same'),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.Conv2D(256, (3, 3), padding='same'),
#     keras.layers.MaxPooling2D((2, 2)),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
    
#     keras.layers.Conv2D(512, (3, 3), padding='same'),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.Conv2D(512, (3, 3), padding='same'),
#     # keras.layers.MaxPooling2D((2, 2)),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
    
#     keras.layers.Conv2D(1024, (3, 3), padding='same'),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.Conv2D(1024, (3, 3), padding='same'),
#     keras.layers.MaxPooling2D((2, 2)),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
    
#     keras.layers.Conv2D(1024, (3, 3), padding='same'),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.Conv2D(1024, (3, 3), padding='same'),
#     # keras.layers.MaxPooling2D((2, 2)),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.GlobalAveragePooling2D(),
    
#     # keras.layers.Flatten(),
#     keras.layers.Dense(512),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.Dense(1024),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.Dense(128),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(config['dropout_rate']),
#     keras.layers.Dense(train_output.shape[1]),
#     keras.layers.Activation('sigmoid'),
# ])

# model.summary()

# %%
model = keras.Sequential([
    layers.InputLayer(input_shape=(train_input.shape[1], train_input.shape[2], 2)),

    layers.Conv2D(64, 3, padding='same'),
    layers.BatchNormalization(),
    layers.LeakyReLU(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(128, 3, padding='same'),
    layers.BatchNormalization(),
    layers.LeakyReLU(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(256, 3, padding='same'),
    layers.BatchNormalization(),
    layers.LeakyReLU(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.Conv2D(512, 3, padding='same'),
    layers.BatchNormalization(),
    layers.LeakyReLU(),
    layers.MaxPooling2D(pool_size=(2, 2)),

    layers.GlobalAveragePooling2D(),

    layers.Dense(128, activation='leaky_relu'),
    layers.Dense(64, activation='leaky_relu'),
    layers.Dense(32, activation='leaky_relu'),
    layers.Dense(8, activation='sigmoid')
])

# %%
# model = keras.Sequential([
#     keras.layers.Conv2D(64, (3, 3), padding='same', input_shape=(train_input.shape[1], train_input.shape[2], 2)),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.MaxPooling2D((2, 2)),
    
#     keras.layers.Conv2D(128, (3, 3), padding='same'),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.MaxPooling2D((2, 2)),
    
#     keras.layers.Conv2D(256, (3, 3), padding='same'),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.GlobalAveragePooling2D(),

#     keras.layers.Dense(128),
#     keras.layers.BatchNormalization(),
#     keras.layers.Activation(config['activation']),
#     keras.layers.Dropout(0.3),
    
#     keras.layers.Dense(train_output.shape[1]),
#     keras.layers.Activation('sigmoid'),
# ])
# model.summary()

# %%
def top2_postprocess(y_pred):
    y_out = np.zeros_like(y_pred)
    top2_idx = np.argsort(y_pred, axis=1)[:, -2:]
    for i in range(len(y_pred)):
        y_out[i, top2_idx[i]] = 1
    return y_out

def exact_match_accuracy(y_true, y_pred):    
    y_pred_binary = tf.cast(y_pred > 0.5, tf.float32)
    # top 2
    # y_pred_binary = top2_postprocess(y_pred.numpy())

    y_true_binary = tf.cast(y_true > 0.5, tf.float32)  # 確保 y_true 也是 float32
    
    # 比對是否逐 row 全部正確
    match = tf.reduce_all(tf.equal(y_true_binary, y_pred_binary), axis=1)

    # 計算準確率
    accuracy = tf.reduce_mean(tf.cast(match, tf.float32))
    
    return accuracy

# %%
def combination_loss(lambda_constraint=1):
    def loss_fn(y_true, y_pred):
        # 二進制交叉熵損失
        # bce_loss = keras.losses.binary_crossentropy(y_true, y_pred, from_logits=True)
        bce_loss = tf.reduce_mean(keras.losses.binary_crossentropy(y_true, y_pred, from_logits=False))
        
        # 約束：只有兩個正數
        positive_count = tf.reduce_sum(y_pred, axis=1)
        # positive_count = tf.reduce_sum(tf.cast(probs > 0.5, tf.float32), axis=1)  # 每行正數的個數
        sum_constraint = tf.reduce_mean(tf.square(positive_count - 2.0))  # 平均每行正數個數與2的差的平方
        # sum_constraint = tf.reduce_mean(tf.square(tf.reduce_sum(y_pred, axis=1) - 2.0))
        
        # 總損失
        total_loss = bce_loss + lambda_constraint * sum_constraint
        return total_loss
    
    return loss_fn

# %%
class PositiveCountMonitor(Callback):
    def __init__(self, test_dataset):
        super().__init__()
        self.test_dataset = test_dataset  # tf.data.Dataset 格式

    def on_epoch_end(self, epoch, logs=None):
        pos_counts = []

        for batch in self.test_dataset:
            x_batch, _ = batch
            y_pred = self.model.predict(x_batch, verbose=0)
            binary_preds = tf.cast(y_pred > 0.5, tf.float32)
            batch_pos_counts = tf.reduce_sum(binary_preds, axis=1).numpy()  # 每個樣本正例數
            pos_counts.extend(batch_pos_counts)

        pos_counts = np.array(pos_counts)
        avg_pos = np.mean(pos_counts)
        std_pos = np.std(pos_counts)

        print(f'\n[monitor] Epoch {epoch+1}: Average positive count: {avg_pos:.2f}, Std: {std_pos:.2f}')

# %%
from tensorflow.keras.optimizers.schedules import CosineDecay

lr_schedule_fn = CosineDecay(initial_learning_rate=config['learning_rate'], decay_steps=config['epochs'] * (total_samples_train // config['batch_size']), alpha=0.2)
# optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule_fn)
optimizer = tf.keras.optimizers.Adam(learning_rate=config['learning_rate'])


model.compile(optimizer = optimizer,
              # loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
            #   loss = tf.keras.losses.BinaryCrossentropy(from_logits=False),
              loss = combination_loss(lambda_constraint = 0.3),
              metrics = [exact_match_accuracy])

lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor='val_exact_match_accuracy', factor=0.5, patience=5, min_lr=1e-6
)

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_exact_match_accuracy', mode='max', patience=10, restore_best_weights=True
)

monitor = PositiveCountMonitor(train_dataset)

# %%
class LrLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer._decayed_lr(tf.float32).numpy()
        print(f"\nEpoch {epoch + 1}: Learning rate is {lr:.6f}")

# %%
# history = model.fit(train_dataset, validation_data=test_dataset, epochs=config['epochs'], batch_size=config['batch_size'], callbacks=[lr_scheduler, early_stopping, monitor], verbose=1)
history = model.fit(train_dataset, validation_data=test_dataset, epochs=config['epochs'], batch_size=config['batch_size'], verbose=1)
# history = model.fit(train_input, train_output, epochs=config['epochs'], batch_size=config['batch_size'], validation_split=0.2, callbacks=[lr_scheduler, early_stopping, monitor], verbose=1)
# Out:
# Epoch 1/50
# 448/448 [==============================] - 7s 14ms/step - loss: 0.4547 - exact_match_accuracy: 0.1639 - val_loss: 0.4036 - val_exact_match_accuracy: 0.2147
# Epoch 2/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.1438 - exact_match_accuracy: 0.7403 - val_loss: 0.6102 - val_exact_match_accuracy: 0.3601
# Epoch 3/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0491 - exact_match_accuracy: 0.9304 - val_loss: 0.6085 - val_exact_match_accuracy: 0.4554
# Epoch 4/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0266 - exact_match_accuracy: 0.9669 - val_loss: 1.5912 - val_exact_match_accuracy: 0.1542
# Epoch 5/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0175 - exact_match_accuracy: 0.9789 - val_loss: 1.5448 - val_exact_match_accuracy: 0.2326
# Epoch 6/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0138 - exact_match_accuracy: 0.9841 - val_loss: 0.7329 - val_exact_match_accuracy: 0.4960
# Epoch 7/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0084 - exact_match_accuracy: 0.9902 - val_loss: 1.1193 - val_exact_match_accuracy: 0.3269
# Epoch 8/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0109 - exact_match_accuracy: 0.9877 - val_loss: 1.6105 - val_exact_match_accuracy: 0.2651
# Epoch 9/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0061 - exact_match_accuracy: 0.9933 - val_loss: 0.8935 - val_exact_match_accuracy: 0.4505
# Epoch 10/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0088 - exact_match_accuracy: 0.9896 - val_loss: 0.5046 - val_exact_match_accuracy: 0.5881
# Epoch 11/50
# 448/448 [==============================] - 7s 14ms/step - loss: 0.0049 - exact_match_accuracy: 0.9944 - val_loss: 0.9221 - val_exact_match_accuracy: 0.4771
# Epoch 12/50
# 448/448 [==============================] - 7s 14ms/step - loss: 0.0109 - exact_match_accuracy: 0.9879 - val_loss: 0.5569 - val_exact_match_accuracy: 0.5864
# Epoch 13/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0036 - exact_match_accuracy: 0.9959 - val_loss: 0.5825 - val_exact_match_accuracy: 0.6164
# Epoch 14/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0045 - exact_match_accuracy: 0.9949 - val_loss: 0.9146 - val_exact_match_accuracy: 0.4793
# Epoch 15/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0080 - exact_match_accuracy: 0.9907 - val_loss: 0.5282 - val_exact_match_accuracy: 0.6655
# Epoch 16/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0037 - exact_match_accuracy: 0.9959 - val_loss: 1.3700 - val_exact_match_accuracy: 0.4052
# Epoch 17/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0041 - exact_match_accuracy: 0.9952 - val_loss: 0.7349 - val_exact_match_accuracy: 0.5600
# Epoch 18/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0065 - exact_match_accuracy: 0.9924 - val_loss: 0.5176 - val_exact_match_accuracy: 0.6743
# Epoch 19/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0036 - exact_match_accuracy: 0.9959 - val_loss: 0.4881 - val_exact_match_accuracy: 0.6761
# Epoch 20/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0050 - exact_match_accuracy: 0.9940 - val_loss: 0.7541 - val_exact_match_accuracy: 0.5811
# Epoch 21/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0031 - exact_match_accuracy: 0.9968 - val_loss: 0.5768 - val_exact_match_accuracy: 0.6000
# Epoch 22/50
# 448/448 [==============================] - 7s 15ms/step - loss: 3.5022e-04 - exact_match_accuracy: 0.9996 - val_loss: 0.2938 - val_exact_match_accuracy: 0.7847
# Epoch 23/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0075 - exact_match_accuracy: 0.9914 - val_loss: 0.6925 - val_exact_match_accuracy: 0.5069
# Epoch 24/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0014 - exact_match_accuracy: 0.9986 - val_loss: 0.2635 - val_exact_match_accuracy: 0.7983
# Epoch 25/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0032 - exact_match_accuracy: 0.9964 - val_loss: 2.0873 - val_exact_match_accuracy: 0.2407
# Epoch 26/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0043 - exact_match_accuracy: 0.9954 - val_loss: 0.7876 - val_exact_match_accuracy: 0.5622
# Epoch 27/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0022 - exact_match_accuracy: 0.9973 - val_loss: 0.5386 - val_exact_match_accuracy: 0.6407
# Epoch 28/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0015 - exact_match_accuracy: 0.9985 - val_loss: 0.5891 - val_exact_match_accuracy: 0.6354
# Epoch 29/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0027 - exact_match_accuracy: 0.9968 - val_loss: 0.9410 - val_exact_match_accuracy: 0.5075
# Epoch 30/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0057 - exact_match_accuracy: 0.9944 - val_loss: 0.4225 - val_exact_match_accuracy: 0.7268
# Epoch 31/50
# 448/448 [==============================] - 7s 15ms/step - loss: 8.1152e-04 - exact_match_accuracy: 0.9991 - val_loss: 0.4572 - val_exact_match_accuracy: 0.7333
# Epoch 32/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0017 - exact_match_accuracy: 0.9980 - val_loss: 0.7109 - val_exact_match_accuracy: 0.6016
# Epoch 33/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0022 - exact_match_accuracy: 0.9978 - val_loss: 0.4299 - val_exact_match_accuracy: 0.7194
# Epoch 34/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0024 - exact_match_accuracy: 0.9976 - val_loss: 0.5924 - val_exact_match_accuracy: 0.6733
# Epoch 35/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0034 - exact_match_accuracy: 0.9964 - val_loss: 0.6633 - val_exact_match_accuracy: 0.6474
# Epoch 36/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0027 - exact_match_accuracy: 0.9974 - val_loss: 0.6922 - val_exact_match_accuracy: 0.6296
# Epoch 37/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0020 - exact_match_accuracy: 0.9979 - val_loss: 0.3729 - val_exact_match_accuracy: 0.7678
# Epoch 38/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0028 - exact_match_accuracy: 0.9973 - val_loss: 0.5562 - val_exact_match_accuracy: 0.6687
# Epoch 39/50
# 448/448 [==============================] - 7s 15ms/step - loss: 5.4321e-04 - exact_match_accuracy: 0.9994 - val_loss: 0.3123 - val_exact_match_accuracy: 0.7969
# Epoch 40/50
# 448/448 [==============================] - 7s 15ms/step - loss: 1.6082e-04 - exact_match_accuracy: 0.9998 - val_loss: 0.5544 - val_exact_match_accuracy: 0.7058
# Epoch 41/50
# 448/448 [==============================] - 7s 14ms/step - loss: 0.0051 - exact_match_accuracy: 0.9945 - val_loss: 0.6860 - val_exact_match_accuracy: 0.6383
# Epoch 42/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0010 - exact_match_accuracy: 0.9988 - val_loss: 0.6797 - val_exact_match_accuracy: 0.6494
# Epoch 43/50
# 448/448 [==============================] - 6s 14ms/step - loss: 0.0012 - exact_match_accuracy: 0.9987 - val_loss: 0.4562 - val_exact_match_accuracy: 0.7051
# Epoch 44/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0030 - exact_match_accuracy: 0.9969 - val_loss: 0.5360 - val_exact_match_accuracy: 0.6928
# Epoch 45/50
# 448/448 [==============================] - 6s 14ms/step - loss: 9.3276e-04 - exact_match_accuracy: 0.9990 - val_loss: 0.5046 - val_exact_match_accuracy: 0.7385
# Epoch 46/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0024 - exact_match_accuracy: 0.9979 - val_loss: 0.7940 - val_exact_match_accuracy: 0.5891
# Epoch 47/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0022 - exact_match_accuracy: 0.9980 - val_loss: 0.4344 - val_exact_match_accuracy: 0.7118
# Epoch 48/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0010 - exact_match_accuracy: 0.9988 - val_loss: 0.4187 - val_exact_match_accuracy: 0.7272
# Epoch 49/50
# 448/448 [==============================] - 7s 15ms/step - loss: 0.0022 - exact_match_accuracy: 0.9978 - val_loss: 0.3853 - val_exact_match_accuracy: 0.7688
# Epoch 50/50
# 448/448 [==============================] - 7s 15ms/step - loss: 8.1837e-04 - exact_match_accuracy: 0.9990 - val_loss: 0.3536 - val_exact_match_accuracy: 0.7829

# %% [markdown]
# # Training result

# %%
# 取出歷史紀錄
# acc = history.history['accuracy']
acc = history.history['exact_match_accuracy']
val_acc = history.history['val_exact_match_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# 畫準確率
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo-', label='training accuracy')
plt.plot(epochs, val_acc, 'ro-', label='validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 畫損失
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo-', label='training loss')
plt.plot(epochs, val_loss, 'ro-', label='validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Test

# %%
model.evaluate(test_dataset, verbose=1)
# Out:
# 112/112 [==============================] - 0s 4ms/step - loss: 0.3536 - exact_match_accuracy: 0.7829
# [0.35362839698791504, 0.7828543782234192]

# %%
predictions = model.predict(test_input)
# print('\nPredictions shape:', predictions.shape)
# predictions = (predictions > 0.5).astype(np.float32)  # 將概率轉換為二進制輸出
predictions = top2_postprocess(predictions)  # 將預測結果轉換為 top-2 的 one-hot 編碼
# print('predictions:', predictions[0:10])  # 顯示前10筆預測結果

sum_is_not_2_cnt = 0
accuracy = 0
for pred, label in zip(predictions, test_output):
    # print('Predicted:', pred, 'True:', label)
    accuracy += (pred == label).all()
    if np.sum(pred) != 2:
        sum_is_not_2_cnt += 1
        
accuracy /= len(predictions)
print('\nExact Match Accuracy:', accuracy)
print('Number of predictions not summing to 2:', sum_is_not_2_cnt)
print('Number of prediction summing to 2 ratio:', (len(predictions) - sum_is_not_2_cnt) / len(predictions))
# Out:
# 448/448 [==============================] - 1s 2ms/step
#
# Exact Match Accuracy: 0.8176618303571429
# Number of predictions not summing to 2: 0
# Number of prediction summing to 2 ratio: 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix, ConfusionMatrixDisplay

# y_true, y_pred 是多標籤格式，例如：
# y_true = np.array([[1, 0, 0, 1, 0, 0, 0, 0], [...], ...])
# y_pred = np.array([[1, 0, 1, 0, 0, 0, 0, 0], [...], ...])

# 計算每個類別的混淆矩陣
cm = multilabel_confusion_matrix(test_output, predictions)

# 類別名稱（可以自己命名）
class_names = [f"Class {i}" for i in range(test_output.shape[1])]

# 畫出每個類別的混淆矩陣
fig, axes = plt.subplots(2, (len(class_names)+1)//2, figsize=(15, 6))
axes = axes.ravel()

for i in range(len(class_names)):
    disp = ConfusionMatrixDisplay(confusion_matrix=cm[i],
                                   display_labels=["Not "+class_names[i], class_names[i]])
    disp.plot(ax=axes[i], values_format='d', cmap='Blues')
    axes[i].set_title(class_names[i])

plt.tight_layout()
plt.show()
