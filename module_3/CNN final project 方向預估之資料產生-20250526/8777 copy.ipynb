# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, Input
from itertools import combinations
from tensorflow.keras.callbacks import Callback
import tensorflow_probability as tfp

# %%
config = {
    'epochs': 50,
    'batch_size': 128,
    'learning_rate': 0.001,
    'activation': 'gelu',
    'dropout_rate': 0.25,
    'val_size': 0.2,
}

# %% [markdown]
# # Data Loader

# %%
def mixup_tf(x, y, alpha=0.3):
    lam = tfp.distributions.Beta(alpha, alpha).sample()
    index = tf.random.shuffle(tf.range(tf.shape(x)[0]))
    x_mix = lam * x + (1 - lam) * tf.gather(x, index)
    y_mix = lam * y + (1 - lam) * tf.gather(y, index)
    return x_mix, y_mix

# %%
file_dir = './radar_data/special/'
# training data
# input
mat = sio.loadmat(file_dir + 'train_Covariance.mat')
train_input = mat['Covariance']
train_input = np.float32(train_input)
# print("train_input shape:", train_input.shape)

# output
mat = sio.loadmat(file_dir + 'train_Label.mat')
train_output_old = mat['Label']
train_output_old = np.float32(train_output_old)
train_output = train_output_old

dataset = tf.data.Dataset.from_tensor_slices((train_input, train_output))
# print orginal number of samples in train_dataset
num_samples_train_org = sum(1 for _ in dataset)
print("Original number of samples in train_dataset:", num_samples_train_org)

# train_dataset = (
#     dataset
#     .shuffle(buffer_size=1000)
#     .batch(config['batch_size'])
#     .map(mixup_tf, num_parallel_calls=tf.data.AUTOTUNE)
#     .prefetch(tf.data.AUTOTUNE)
# )

# Mixup 的資料集（先 shuffle 才 batch 才 mix）
mix_dataset = (
    dataset
    .shuffle(num_samples_train_org)  # shuffle before batching
    .batch(config['batch_size'])
    .map(mixup_tf, num_parallel_calls=tf.data.AUTOTUNE)
    .unbatch()  # 重要！把 mixup 的 batch 還原，才能與原始資料合併
)
# # 輸出 mix_dataset 的label example
# for batch in mix_dataset.take(5):
#     mix_input, mix_output = batch
#     print("Mixup output:", mix_output)


# 合併原始與 mix 資料
combined_dataset = dataset.concatenate(mix_dataset).shuffle(num_samples_train_org * 2)

# for batch in combined_dataset.take(10):
#     input_example, output_example = batch
#     print("Combined output example:", output_example)



# 將 validation 資料從原始資料中移除
# train_dataset = combined_dataset.skip(int(num_samples_train_org * config['val_size']))

train_dataset = (
    combined_dataset
    .batch(config['batch_size'])
    .prefetch(tf.data.AUTOTUNE)
)
    
# print("train_dataset.shape:", train_dataset.element_spec)
# print number of samples in train_dataset
total_samples_train = sum(batch[0].shape[0] for batch in train_dataset)
print("Total number of training samples (after batching):", total_samples_train)



# testing data
# input
mat = sio.loadmat(file_dir + 'test_Covariance.mat')
test_input = mat['Covariance']
test_input = np.float32(test_input)
# print("test_input shape:", test_input.shape)

# output
mat = sio.loadmat(file_dir + 'test_Label.mat')
test_output_old = mat['Label']
test_output_old = np.float32(test_output_old)
test_output = test_output_old

dataset = tf.data.Dataset.from_tensor_slices((test_input, test_output))
test_dataset = dataset.batch(config['batch_size']).prefetch(tf.data.AUTOTUNE)

# print("test_output shape:", test_output.shape)
# print("test_dataset.shape:", test_dataset.element_spec)
# print number of samples in test_dataset
total_samples_test = sum(batch[0].shape[0] for batch in test_dataset)
print("Total number of testing samples (after batching):", total_samples_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 file_dir = './radar_data/special/'
#       2 # training data
#       3 # input
# ----> 4 mat = sio.loadmat(file_dir + 'train_Covariance.mat')
#       5 train_input = mat['Covariance']
#       6 train_input = np.float32(train_input)
#
# NameError: name 'sio' is not defined

# %% [markdown]
# # model

# %%
model = keras.Sequential([
    keras.layers.Conv2D(128, (3, 3), input_shape=(train_input.shape[1], train_input.shape[2], 2)),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    keras.layers.Conv2D(128, (3, 3), padding='same'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    
    keras.layers.Conv2D(256, (3, 3), padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    keras.layers.Conv2D(256, (3, 3), padding='same'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    
    keras.layers.Conv2D(512, (3, 3), padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    keras.layers.Conv2D(512, (3, 3), padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    
    keras.layers.Conv2D(1024, (3, 3), padding='same'),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    keras.layers.Conv2D(1024, (3, 3), padding='same'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    
    keras.layers.GlobalAveragePooling2D(),
    
    keras.layers.Dense(512),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    keras.layers.Dropout(config['dropout_rate']),
    keras.layers.Dense(1024),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    keras.layers.Dropout(config['dropout_rate']),
    keras.layers.Dense(128),
    keras.layers.BatchNormalization(),
    keras.layers.LeakyReLU(alpha=0.3),
    keras.layers.Dropout(config['dropout_rate']),
    keras.layers.Dense(train_output.shape[1]),
    keras.layers.Activation('sigmoid'),
])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_52 (Conv2D)          (None, 30, 30, 128)       2432
#
#  batch_normalization_70 (Bat  (None, 30, 30, 128)      512
#  chNormalization)
#
#  leaky_re_lu_70 (LeakyReLU)  (None, 30, 30, 128)       0
#
#  conv2d_53 (Conv2D)          (None, 30, 30, 128)       147584
#
#  max_pooling2d_18 (MaxPoolin  (None, 15, 15, 128)      0
#  g2D)
#
#  batch_normalization_71 (Bat  (None, 15, 15, 128)      512
#  chNormalization)
#
#  leaky_re_lu_71 (LeakyReLU)  (None, 15, 15, 128)       0
#
#  conv2d_54 (Conv2D)          (None, 15, 15, 256)       295168
#
#  batch_normalization_72 (Bat  (None, 15, 15, 256)      1024
#  chNormalization)
#
#  leaky_re_lu_72 (LeakyReLU)  (None, 15, 15, 256)       0
#
#  conv2d_55 (Conv2D)          (None, 15, 15, 256)       590080
#
#  max_pooling2d_19 (MaxPoolin  (None, 7, 7, 256)        0
#  g2D)
#
#  batch_normalization_73 (Bat  (None, 7, 7, 256)        1024
#  chNormalization)
#
#  leaky_re_lu_73 (LeakyReLU)  (None, 7, 7, 256)         0
#
#  conv2d_56 (Conv2D)          (None, 7, 7, 512)         1180160
#
#  batch_normalization_74 (Bat  (None, 7, 7, 512)        2048
#  chNormalization)
#
#  leaky_re_lu_74 (LeakyReLU)  (None, 7, 7, 512)         0
#
#  conv2d_57 (Conv2D)          (None, 7, 7, 512)         2359808
#
#  batch_normalization_75 (Bat  (None, 7, 7, 512)        2048
#  chNormalization)
#
#  leaky_re_lu_75 (LeakyReLU)  (None, 7, 7, 512)         0
#
#  conv2d_58 (Conv2D)          (None, 7, 7, 1024)        4719616
#
#  batch_normalization_76 (Bat  (None, 7, 7, 1024)       4096
#  chNormalization)
#
#  leaky_re_lu_76 (LeakyReLU)  (None, 7, 7, 1024)        0
#
#  conv2d_59 (Conv2D)          (None, 7, 7, 1024)        9438208
#
#  max_pooling2d_20 (MaxPoolin  (None, 3, 3, 1024)       0
#  g2D)
#
#  batch_normalization_77 (Bat  (None, 3, 3, 1024)       4096
#  chNormalization)
#
#  leaky_re_lu_77 (LeakyReLU)  (None, 3, 3, 1024)        0
#
#  global_average_pooling2d_6   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_24 (Dense)            (None, 512)               524800
#
#  batch_normalization_78 (Bat  (None, 512)              2048
#  chNormalization)
#
#  leaky_re_lu_78 (LeakyReLU)  (None, 512)               0
#
#  dropout_15 (Dropout)        (None, 512)               0
#
#  dense_25 (Dense)            (None, 1024)              525312
#
#  batch_normalization_79 (Bat  (None, 1024)             4096
#  chNormalization)
#
#  leaky_re_lu_79 (LeakyReLU)  (None, 1024)              0
#
#  dropout_16 (Dropout)        (None, 1024)              0
#
#  dense_26 (Dense)            (None, 128)               131200
#
#  batch_normalization_80 (Bat  (None, 128)              512
#  chNormalization)
#
#  leaky_re_lu_80 (LeakyReLU)  (None, 128)               0
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 8)                 1032
#
#  activation_6 (Activation)   (None, 8)                 0
#
# =================================================================
# Total params: 19,937,416
# Trainable params: 19,926,408
# Non-trainable params: 11,008
# _________________________________________________________________

# %%
# model = keras.Sequential([
#     layers.InputLayer(input_shape=(train_input.shape[1], train_input.shape[2], 2)),

#     layers.Conv2D(64, 3, padding='same'),
#     layers.BatchNormalization(),
#     # keras.layers.Activation(config['activation']),
#     layers.LeakyReLU(alpha=0.3),
#     layers.MaxPooling2D(pool_size=(2, 2)),

#     layers.Conv2D(128, 3, padding='same'),
#     layers.BatchNormalization(),
#     # keras.layers.Activation(config['activation']),
#     layers.LeakyReLU(alpha=0.3),
#     layers.MaxPooling2D(pool_size=(2, 2)),

#     layers.Conv2D(256, 3, padding='same'),
#     layers.BatchNormalization(),
#     # keras.layers.Activation(config['activation']),
#     layers.LeakyReLU(alpha=0.3),
#     layers.MaxPooling2D(pool_size=(2, 2)),

#     layers.Conv2D(512, 3, padding='same'),
#     layers.BatchNormalization(),
#     # keras.layers.Activation(config['activation']),
#     layers.LeakyReLU(alpha=0.3),
#     layers.MaxPooling2D(pool_size=(2, 2)),

#     layers.GlobalAveragePooling2D(),

#     layers.Dense(128),
#     # layers.BatchNormalization(),
#     layers.LeakyReLU(alpha=0.3),
#     layers.Dense(64),
#     # layers.BatchNormalization(),
#     layers.LeakyReLU(alpha=0.3),
#     layers.Dense(32),
#     # layers.BatchNormalization(),
#     layers.LeakyReLU(alpha=0.3),
#     # layers.Dropout(0.25),
#     layers.Dense(8, activation='sigmoid')
# ])

# %%
def top2_postprocess(y_pred):
    y_out = np.zeros_like(y_pred)
    top2_idx = np.argsort(y_pred, axis=1)[:, -2:]
    for i in range(len(y_pred)):
        y_out[i, top2_idx[i]] = 1
    return y_out

def exact_match_accuracy(y_true, y_pred):    
    y_pred_binary = tf.cast(y_pred > 0.5, tf.float32)
    y_true_binary = tf.cast(y_true > 0.5, tf.float32)
    
    # 比對是否逐 row 全部正確
    match = tf.reduce_all(tf.equal(y_true_binary, y_pred_binary), axis=1)

    # 計算準確率
    accuracy = tf.reduce_mean(tf.cast(match, tf.float32))
    
    return accuracy

# %%
def combination_loss(lambda_constraint=0.3):
    def loss_fn(y_true, y_pred):
        bce_loss = tf.reduce_mean(keras.losses.binary_crossentropy(y_true, y_pred, from_logits=False))
        
        positive_count = tf.reduce_sum(y_pred, axis=1)
        sum_constraint = tf.reduce_mean(tf.square(positive_count - 2.0))
        
        total_loss = bce_loss + lambda_constraint * sum_constraint
        return total_loss
    
    return loss_fn

# %%
class PositiveCountMonitor(Callback):
    def __init__(self, test_dataset):
        super().__init__()
        self.test_dataset = test_dataset  # tf.data.Dataset 格式

    def on_epoch_end(self, epoch, logs=None):
        pos_counts = []

        for batch in self.test_dataset:
            x_batch, _ = batch
            y_pred = self.model.predict(x_batch, verbose=0)
            binary_preds = tf.cast(y_pred > 0.5, tf.float32)
            batch_pos_counts = tf.reduce_sum(binary_preds, axis=1).numpy()  # 每個樣本正例數
            pos_counts.extend(batch_pos_counts)

        pos_counts = np.array(pos_counts)
        avg_pos = np.mean(pos_counts)
        std_pos = np.std(pos_counts)

        print(f'\n[monitor] Epoch {epoch+1}: Average positive count: {avg_pos:.2f}, Std: {std_pos:.2f}')

# %%
from tensorflow.keras.optimizers.schedules import CosineDecay

lr_schedule_fn = CosineDecay(initial_learning_rate=config['learning_rate'], decay_steps=config['epochs'] * (total_samples_train // config['batch_size']), alpha=0.2)
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule_fn)
# optimizer = tf.keras.optimizers.Adam(learning_rate=config['learning_rate'])


model.compile(optimizer = optimizer,
              # loss = tf.keras.losses.CategoricalCrossentropy(from_logits=True),
            #   loss = tf.keras.losses.BinaryCrossentropy(from_logits=False),
              loss = combination_loss(),
              metrics = [exact_match_accuracy])

lr_scheduler = keras.callbacks.ReduceLROnPlateau(
    monitor='val_exact_match_accuracy', factor=0.5, patience=5, min_lr=1e-6
)

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_exact_match_accuracy', mode='max', patience=10, restore_best_weights=True
)

monitor = PositiveCountMonitor(train_dataset)

# %%
class LrLogger(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        lr = self.model.optimizer._decayed_lr(tf.float32).numpy()
        print(f"\nEpoch {epoch + 1}: Learning rate is {lr:.6f}")

# %%
# history = model.fit(train_dataset, validation_data=test_dataset, epochs=config['epochs'], batch_size=config['batch_size'], callbacks=[lr_scheduler, early_stopping, monitor], verbose=1)
history = model.fit(train_dataset, validation_data=test_dataset, epochs=config['epochs'], batch_size=config['batch_size'], verbose=1)
# history = model.fit(train_input, train_output, epochs=config['epochs'], batch_size=config['batch_size'], validation_split=0.2, callbacks=[lr_scheduler, early_stopping, monitor], verbose=1)
# Out:
# Epoch 1/50
# 896/896 [==============================] - 103s 112ms/step - loss: 0.2786 - exact_match_accuracy: 0.5809 - val_loss: 0.3409 - val_exact_match_accuracy: 0.4936
# Epoch 2/50
# 896/896 [==============================] - 102s 113ms/step - loss: 0.0982 - exact_match_accuracy: 0.9237 - val_loss: 0.1758 - val_exact_match_accuracy: 0.7061
# Epoch 3/50
# 896/896 [==============================] - 101s 112ms/step - loss: 0.0922 - exact_match_accuracy: 0.9292 - val_loss: 0.1899 - val_exact_match_accuracy: 0.7074
# Epoch 4/50
# 896/896 [==============================] - 104s 115ms/step - loss: 0.0895 - exact_match_accuracy: 0.9354 - val_loss: 0.1792 - val_exact_match_accuracy: 0.7199
# Epoch 5/50
# 896/896 [==============================] - 102s 113ms/step - loss: 0.0894 - exact_match_accuracy: 0.9366 - val_loss: 0.1924 - val_exact_match_accuracy: 0.7754
# Epoch 6/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0822 - exact_match_accuracy: 0.9457 - val_loss: 0.5805 - val_exact_match_accuracy: 0.5530
# Epoch 7/50
# 896/896 [==============================] - 101s 112ms/step - loss: 0.0812 - exact_match_accuracy: 0.9457 - val_loss: 0.2136 - val_exact_match_accuracy: 0.7253
# Epoch 8/50
# 896/896 [==============================] - 101s 112ms/step - loss: 0.0838 - exact_match_accuracy: 0.9408 - val_loss: 0.1557 - val_exact_match_accuracy: 0.8126
# Epoch 9/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0776 - exact_match_accuracy: 0.9498 - val_loss: 0.1898 - val_exact_match_accuracy: 0.7979
# Epoch 10/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0806 - exact_match_accuracy: 0.9395 - val_loss: 0.1262 - val_exact_match_accuracy: 0.8209
# Epoch 11/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0807 - exact_match_accuracy: 0.9453 - val_loss: 0.1377 - val_exact_match_accuracy: 0.8026
# Epoch 12/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0757 - exact_match_accuracy: 0.9534 - val_loss: 0.0919 - val_exact_match_accuracy: 0.8433
# Epoch 13/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0728 - exact_match_accuracy: 0.9482 - val_loss: 0.1235 - val_exact_match_accuracy: 0.8331
# Epoch 14/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0774 - exact_match_accuracy: 0.9463 - val_loss: 0.1104 - val_exact_match_accuracy: 0.8523
# Epoch 15/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0772 - exact_match_accuracy: 0.9428 - val_loss: 0.1252 - val_exact_match_accuracy: 0.8103
# Epoch 16/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0761 - exact_match_accuracy: 0.9420 - val_loss: 0.0886 - val_exact_match_accuracy: 0.8473
# Epoch 17/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0734 - exact_match_accuracy: 0.9466 - val_loss: 0.1107 - val_exact_match_accuracy: 0.8349
# Epoch 18/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0722 - exact_match_accuracy: 0.9497 - val_loss: 0.0934 - val_exact_match_accuracy: 0.8449
# Epoch 19/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0749 - exact_match_accuracy: 0.9463 - val_loss: 0.1124 - val_exact_match_accuracy: 0.8472
# Epoch 20/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0678 - exact_match_accuracy: 0.9547 - val_loss: 0.1390 - val_exact_match_accuracy: 0.8437
# Epoch 21/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0713 - exact_match_accuracy: 0.9426 - val_loss: 0.1365 - val_exact_match_accuracy: 0.8449
# Epoch 22/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0801 - exact_match_accuracy: 0.9387 - val_loss: 0.1122 - val_exact_match_accuracy: 0.8576
# Epoch 23/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0730 - exact_match_accuracy: 0.9494 - val_loss: 0.1225 - val_exact_match_accuracy: 0.8476
# Epoch 24/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0683 - exact_match_accuracy: 0.9505 - val_loss: 0.1094 - val_exact_match_accuracy: 0.8482
# Epoch 25/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0671 - exact_match_accuracy: 0.9533 - val_loss: 0.1149 - val_exact_match_accuracy: 0.8366
# Epoch 26/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0737 - exact_match_accuracy: 0.9474 - val_loss: 0.1196 - val_exact_match_accuracy: 0.8639
# Epoch 27/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0726 - exact_match_accuracy: 0.9503 - val_loss: 0.1154 - val_exact_match_accuracy: 0.8576
# Epoch 28/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0700 - exact_match_accuracy: 0.9489 - val_loss: 0.1144 - val_exact_match_accuracy: 0.8440
# Epoch 29/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0700 - exact_match_accuracy: 0.9480 - val_loss: 0.1079 - val_exact_match_accuracy: 0.8561
# Epoch 30/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0662 - exact_match_accuracy: 0.9513 - val_loss: 0.1265 - val_exact_match_accuracy: 0.8508
# Epoch 31/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0677 - exact_match_accuracy: 0.9585 - val_loss: 0.0966 - val_exact_match_accuracy: 0.8665
# Epoch 32/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0661 - exact_match_accuracy: 0.9521 - val_loss: 0.1276 - val_exact_match_accuracy: 0.8425
# Epoch 33/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0733 - exact_match_accuracy: 0.9516 - val_loss: 0.1002 - val_exact_match_accuracy: 0.8521
# Epoch 34/50
# 896/896 [==============================] - 100s 111ms/step - loss: 0.0694 - exact_match_accuracy: 0.9488 - val_loss: 0.1110 - val_exact_match_accuracy: 0.8553
# Epoch 35/50
# 896/896 [==============================] - 101s 112ms/step - loss: 0.0666 - exact_match_accuracy: 0.9513 - val_loss: 0.0983 - val_exact_match_accuracy: 0.8491
# Epoch 36/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0672 - exact_match_accuracy: 0.9539 - val_loss: 0.1189 - val_exact_match_accuracy: 0.8514
# Epoch 37/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0718 - exact_match_accuracy: 0.9458 - val_loss: 0.1005 - val_exact_match_accuracy: 0.8590
# Epoch 38/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0673 - exact_match_accuracy: 0.9585 - val_loss: 0.1498 - val_exact_match_accuracy: 0.8488
# Epoch 39/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0667 - exact_match_accuracy: 0.9604 - val_loss: 0.1349 - val_exact_match_accuracy: 0.8448
# Epoch 40/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0687 - exact_match_accuracy: 0.9506 - val_loss: 0.1491 - val_exact_match_accuracy: 0.8444
# Epoch 41/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0665 - exact_match_accuracy: 0.9533 - val_loss: 0.1126 - val_exact_match_accuracy: 0.8533
# Epoch 42/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0679 - exact_match_accuracy: 0.9532 - val_loss: 0.1336 - val_exact_match_accuracy: 0.8560
# Epoch 43/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0679 - exact_match_accuracy: 0.9488 - val_loss: 0.1051 - val_exact_match_accuracy: 0.8584
# Epoch 44/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0639 - exact_match_accuracy: 0.9585 - val_loss: 0.1319 - val_exact_match_accuracy: 0.8497
# Epoch 45/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0616 - exact_match_accuracy: 0.9557 - val_loss: 0.1062 - val_exact_match_accuracy: 0.8567
# Epoch 46/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0700 - exact_match_accuracy: 0.9538 - val_loss: 0.1095 - val_exact_match_accuracy: 0.8600
# Epoch 47/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0676 - exact_match_accuracy: 0.9479 - val_loss: 0.1235 - val_exact_match_accuracy: 0.8548
# Epoch 48/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0644 - exact_match_accuracy: 0.9566 - val_loss: 0.1150 - val_exact_match_accuracy: 0.8538
# Epoch 49/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0682 - exact_match_accuracy: 0.9585 - val_loss: 0.1315 - val_exact_match_accuracy: 0.8508
# Epoch 50/50
# 896/896 [==============================] - 99s 110ms/step - loss: 0.0676 - exact_match_accuracy: 0.9606 - val_loss: 0.1336 - val_exact_match_accuracy: 0.8501

# %% [markdown]
# # Training result

# %%
# 取出歷史紀錄
# acc = history.history['accuracy']
acc = history.history['exact_match_accuracy']
val_acc = history.history['val_exact_match_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# 畫準確率
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo-', label='training accuracy')
plt.plot(epochs, val_acc, 'ro-', label='validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# 畫損失
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo-', label='training loss')
plt.plot(epochs, val_loss, 'ro-', label='validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Test

# %%
model.evaluate(test_dataset, verbose=1)
# Out:
# 112/112 [==============================] - 4s 33ms/step - loss: 0.1336 - exact_match_accuracy: 0.8501
# [0.13359563052654266, 0.85009765625]

# %%
predictions = model.predict(test_input)
# print('\nPredictions shape:', predictions.shape)
predictions_threshold = (predictions > 0.5).astype(np.float32)  # 將概率轉換為二進制輸出
predictions_top2 = top2_postprocess(predictions)  # 將預測結果轉換為 top-2 的 one-hot 編碼
# print('predictions:', predictions[0:10])  # 顯示前10筆預測結果

sum_is_not_2_cnt = 0
accuracy_thresold = 0
for pred, label in zip(predictions_threshold, test_output):
    # print('Predicted:', pred, 'True:', label)
    accuracy_thresold += (pred == label).all()
    if np.sum(pred) != 2:
        sum_is_not_2_cnt += 1

accuracy_thresold /= len(predictions)

accuracy_top2 = 0
for pred, label in zip(predictions_top2, test_output):
    # print('Predicted:', pred, 'True:', label)
    accuracy_top2 += (pred == label).all()

accuracy_top2 /= len(predictions)
        
print('\nExact Match Accuracy:', accuracy_thresold)
print('Top-2 Exact Match Accuracy:', accuracy_top2)

print('Number of predictions not summing to 2:', sum_is_not_2_cnt)
print('Number of prediction summing to 2 ratio:', (len(predictions) - sum_is_not_2_cnt) / len(predictions))
# Out:
# 448/448 [==============================] - 4s 9ms/step
#
# Exact Match Accuracy: 0.8501674107142857
# Top-2 Exact Match Accuracy: 0.92529296875
# Number of predictions not summing to 2: 1766
# Number of prediction summing to 2 ratio: 0.8768136160714286

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix, ConfusionMatrixDisplay

# y_true, y_pred 是多標籤格式，例如：
# y_true = np.array([[1, 0, 0, 1, 0, 0, 0, 0], [...], ...])
# y_pred = np.array([[1, 0, 1, 0, 0, 0, 0, 0], [...], ...])

# 計算每個類別的混淆矩陣
cm = multilabel_confusion_matrix(test_output, predictions_threshold)

# 類別名稱（可以自己命名）
class_names = [f"Class {i}" for i in range(test_output.shape[1])]

# 畫出每個類別的混淆矩陣
fig, axes = plt.subplots(2, (len(class_names)+1)//2, figsize=(15, 6))
axes = axes.ravel()

for i in range(len(class_names)):
    disp = ConfusionMatrixDisplay(confusion_matrix=cm[i],
                                   display_labels=["Not "+class_names[i], class_names[i]])
    disp.plot(ax=axes[i], values_format='d', cmap='Blues')
    axes[i].set_title(class_names[i])

plt.tight_layout()
plt.show()
